# %% [markdown]
# # Table of Contents
# #### 01. Importing
# #### 02. Data Wrangling Procedures
# #### 03. Data Consistency Checks
# #### 04. Export Data

# %% [markdown]
# # 01. Importing

# %%
# Importing Libraries
import pandas as pd
import numpy as np
import os

# %%
# Path
path =r'/Users/heathervisentin/Desktop/Data Analysis/Achievement 6/World Happiness Report'

# %%
# Importing Data
df = pd.read_excel(os.path.join(path, '02 Data', 'Prepared Data', 'World Happiness merged with region.xlsx'), index_col = False)

# %%
df.head()
# Out:
#        Country  Year          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  2015  Western Europe               1            7.587
# 1      Iceland  2015  Western Europe               2            7.561
# 2      Denmark  2015  Western Europe               3            7.527
# 3       Norway  2015  Western Europe               4            7.522
# 4       Canada  2015   North America               5            7.427
#
#    GDP per Capita  Social Spport  Life Expectancy  Freedom  \
# 0         1.39651        1.34951          0.94143  0.66557
# 1         1.30232        1.40223          0.94784  0.62877
# 2         1.32548        1.36058          0.87464  0.64938
# 3         1.45900        1.33095          0.88521  0.66973
# 4         1.32629        1.32261          0.90563  0.63297
#
#    Government Corruption  Generosity  Dystopia Residual
# 0                0.41978     0.29678            2.51738
# 1                0.14145     0.43630            2.70201
# ...

# %% [markdown]
# # 02. Data Wrangling Procedures

# %%
# Dropping region due to inconsistencies
df_new=df.drop(columns = ['Region'])

# %% [markdown]
# # 03. Data Consistency Checks

# %%
df_new.describe()
# Out:
#               Year  Happiness Rank  Happiness Score  GDP per Capita  \
# count  1084.000000     1084.000000      1084.000000     1084.000000
# mean   2017.968635       77.950185         5.413460        3.269365
# std       1.995594       44.766196         1.118595        3.854953
# min    2015.000000        1.000000         2.523000        0.000000
# 25%    2016.000000       39.000000         4.571000        0.780500
# 50%    2018.000000       78.000000         5.385150        1.170350
# 75%    2020.000000      117.000000         6.216125        7.640969
# max    2021.000000      158.000000         7.842000       11.647000
#
#        Social Spport  Life Expectancy      Freedom  Government Corruption  \
# count    1084.000000      1084.000000  1084.000000            1083.000000
# mean        1.004091        18.471404     0.515936               0.294111
# std         0.310650        28.981743     0.221478               0.300707
# ...

# %%
# Finding missing values
df_new.isnull().sum()
# Out:
# Country                    0
# Year                       0
# Happiness Rank             0
# Happiness Score            0
# GDP per Capita             0
# Social Spport              0
# Life Expectancy            0
# Freedom                    0
# Government Corruption      1
# Generosity                 0
# Dystopia Residual        312
# dtype: int64

# %%
# Viewing missing values
df_nan = df_new[df_new['Dystopia Residual'].isnull() == True]

# %%
df_nan
# Out:
#                       Country  Year  Happiness Rank  Happiness Score  \
# 470                   Finland  2018               1            7.632
# 471                    Norway  2018               2            7.594
# 472                   Denmark  2018               3            7.555
# 473                   Iceland  2018               4            7.495
# 474               Switzerland  2018               5            7.487
# ..                        ...   ...             ...              ...
# 777                    Rwanda  2019             152            3.334
# 778                  Tanzania  2019             153            3.231
# 779               Afghanistan  2019             154            3.203
# 780  Central African Republic  2019             155            3.083
# 781               South Sudan  2019             156            2.853
#
#      GDP per Capita  Social Spport  Life Expectancy  Freedom  \
# 470           1.305          1.592            0.874    0.681
# ...

# %%
# Finding duplicates
df_dups = df_new[df_new.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [Country, Year, Happiness Rank, Happiness Score, GDP per Capita, Social Spport, Life Expectancy, Freedom, Government Corruption, Generosity, Dystopia Residual]
# Index: []

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1084 entries, 0 to 1083
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                1084 non-null   object
#  1   Year                   1084 non-null   int64
#  2   Happiness Rank         1084 non-null   int64
#  3   Happiness Score        1084 non-null   float64
#  4   GDP per Capita         1084 non-null   float64
#  5   Social Spport          1084 non-null   float64
#  6   Life Expectancy        1084 non-null   float64
#  7   Freedom                1084 non-null   float64
#  8   Government Corruption  1083 non-null   float64
#  9   Generosity             1084 non-null   float64
#  10  Dystopia Residual      772 non-null    float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 93.3+ KB
